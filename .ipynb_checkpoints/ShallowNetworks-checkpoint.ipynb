# %% [markdown]
# > Pacotes necessários

# %%
import scipy
from PIL import Image
import numpy as np
import os
import matplotlib.pylab as plt
import matplotlib.image as mpimg
import importlib

# %% [markdown]
# > Esta célula corre todas as funções de ativação e as suas derivadas

# %%
# sigmoid function
def sigmoid(z):
    s = 1 / (1 + np.exp(-z));
    return s;

# relu function
def relu(z):
    return np.where( z <= 0, 0 , z)

#derivada sigmoid
def der_sigmoid(z):
   return sigmoid(1-sigmoid(z))

#derivada tangente hiperbólica
def der_tanh(z):
    return (1-np.power(z,2))

#derivada relu
def der_relu(z):
    z[z<=0] = 0
    z[z>0] = 1
    return z

#normalization
def normalization(ew):
    return(ew/np.linalg.norm(ew,2))

# %% [markdown]
# > Esta célula inicializa os parãmetros de uma rede neuronal, neste caso temos apenas dois layers
#
# > Input -> Hidden Layer -> Output

# %%
# size of the fst and the last layer, and the hidden layer
# assuming 1 hidden layer
def inicializar_parameters(n_x,n_h,n_y):
    
    #w1 = np.zeros((n_h,n_x))
    #w1 = normalization(w1)
    w1 = np.random.randn(n_h,n_x) * 0.01;
    b1 = np.zeros((n_h,1));
    
    #w2 = np.zeros((n_y,n_h))
    #w2 = normalization(w2)
    w2 = np.random.randn(n_y,n_h) * 0.01;
    b2 = np.zeros((n_y,1));

    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2
    }

    return parameters;

# %% [markdown]
# > Esta célula faz o feed forward da rede, neste caso temos que especificar as funções de ativação
#
# > Input -> Função linear(z1) -> Função de Ativação -> Função linear(Z2) -> Função de Ativação(Sigmoid) (output)

# %%
# i use the non-linear activation function called than, in the output layer i use sigmoid, cause this is a binary classification problem.
def feed_forward(X,parameters,activation):
    
    
    w1 = parameters["w1"];
    b1 = parameters["b1"];
    w2 = parameters["w2"];
    b2 = parameters["b2"];

    #feed_foward
    Z1 = np.dot(w1,X) + b1; 

    
    if(activation == "tanh"):
        A1 = np.tanh(Z1);
    elif(activation == "relu"):
        A1 = relu(Z1);
    elif(activation == "sigmoid"):
        A1 = sigmoid(Z1);
        
    Z2 = np.dot(w2,A1) + b2;
    A2 = sigmoid(Z2);

    cache = {
        "Z1" : Z1,
        "A1" : A1,
        "Z2" : Z2,
        "A2" : A2
    }

    return A2, cache;

# %% [markdown]
# > Função custo

# %%
def calculate_cost(A2,Yt):
    #para não estar a fazer log de 0 acrescenta-se um teta
    e = 0.000000001
    Cost = - np.sum(np.dot(Yt, np.log(A2+e).T) + np.dot(1 - Yt, np.log(1 - A2+e).T)) /m;  #cost function

    return Cost;

# %% [markdown]
# > Back propagation da rede, preciso as funções de ativação

# %%
def back_propagation(X,Y,cache,parameters,activation):

    A1 = cache["A1"];
    w1 = parameters["w1"];
    w2 = parameters["w2"];
    A2 = cache["A2"];
    
    dZ2 = A2 - Y;
    dW2 = np.dot(dZ2,A1.T)/m;
    dB2 = np.sum(dZ2, axis=1, keepdims = True)/m;
    
    if(activation == "relu"):
        dZ1 = np.multiply(np.dot(w2.T,dZ2), der_relu(A1));
    if(activation == "tanh"):
        dZ1 = np.multiply(np.dot(w2.T,dZ2), 1 - np.power(A1, 2));
    if(activation == "sigmoid"):
        dZ1 = np.multiply(np.dot(w2.T,dZ2),der_sigmoid(A1));
    dW1 = np.dot(dZ1,X.T)/m;
    dB1 = np.sum(dZ1,axis = 1, keepdims = True)/m;

    grads = {
        "dW2" : dW2,
        "dB2" : dB2,
        "dW1" : dW1,
        "dB1" : dB1
    }

    return grads;

# %% [markdown]
# > Otimização de parâmetros, feito após ter corrido o back propagation, e obtido os respetivos gradientes

# %%
def otimize_parameters(parameters,grads,learning_rate):
    
    w1 = parameters["w1"];
    w2 = parameters["w2"];
    b1 = parameters["b1"];
    b2 = parameters["b2"];

    
    dW2 = grads["dW2"];
    dB2 = grads["dB2"];
    dW1 = grads["dW1"];
    dB1 = grads["dB1"];

    #uptade de parameters
    w2 = w2 - learning_rate * dW2;
    w1 = w1 - learning_rate * dW1;
    b1 = b1 - learning_rate * dB1;
    b2 = b2 - learning_rate * dB2;

    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2
    }

    return parameters;

# %%
def read_asc_data(filename):    
    f= open(filename,'r') 
    tmp_str=f.readline()
    tmp_arr=tmp_str[:-1].split(' ')
    N=int(tmp_arr[0]);n_row=int(tmp_arr[1]);n_col=int(tmp_arr[2])
    data=np.zeros([N,n_row*n_col+1])
    for n in range(N):
        tmp_str=f.readline()
        tmp_arr=tmp_str[:-1].split(' ')       
        for i in range(n_row*n_col+1):
            data[n][i]=int(tmp_arr[i])
    f.close() 
    return N,n_row,n_col,data

# %%
def model(n_h,number_iterations,learning_rate,activation):

    np.random.seed(3) # we set up a seed so that your output matches ours although the initialization is random.
    parameters = inicializar_parameters(Xt.shape[0],n_h,Yt.shape[0]);
    
    #previous_cost vai ser similar a um eraly stopping neste problema, qd o custo não diminuir em 100 epochs para de treinar
    previous_cost = 1e3 
    
    for i in range(0,number_iterations):

        A2, cache = feed_forward(Xt,parameters,activation);
        grads = back_propagation(Xt,Yt,cache,parameters,activation);
        parameters = otimize_parameters(parameters,grads,learning_rate);
        
        if(i%100 == 0):
            cost = calculate_cost(A2,Yt)
            print("Cost of iteration " + str(i) + "= " + str(cost));
            
            if(cost >= previous_cost):
                break
            
            previous_cost = cost
            

    return parameters;

# %%
# =========== Setting dataset ================
#N,n_row,n_col,data=read_asc_data('./line600.txt')
N,n_row,n_col,data=read_asc_data('./square_circle.txt')
print('find %d images of %d X %d pixels' % (N,n_row,n_col))

#plot_data(10,10,n_row,n_col,data)
Nt=int(N*0.8);I=n_row*n_col; #split training vs test sets
Xt=data[:Nt,:-1];Yt=data[:Nt,-1]
Yt = Yt.reshape(len(Yt),1)

np.place(Yt, Yt!=1, [0])
m = Xt.shape[0]

Xt = Xt.T
Yt = Yt.T

#funções de ativação disponíveis por agora
# * Relu
# * Tanh
# * Sigmoid
activation_function = "tanh"
parameters = model(1,20000,0.01,activation_function)
# Out:
# find 1500 images of 12 X 12 pixels
# Cost of iteration 0= 0.6931322074788115
# Cost of iteration 100= 0.6930409080888116
# Cost of iteration 200= 0.6929701698894042
# Cost of iteration 14500= 0.010320192698812868
# Cost of iteration 14600= 0.010223934115645941
# Cost of iteration 14700= 0.010129407569405897
# Cost of iteration 14800= 0.010036567442027484
# Cost of iteration 14900= 0.009945369686255385
# Cost of iteration 15000= 0.009855771759173087
# Cost of iteration 15100= 0.009767732559055652
# Cost of iteration 15200= 0.009681212365355412
# Cost of iteration 15300= 0.009596172781641347
# Cost of iteration 15400= 0.009512576681325647
# Cost of iteration 15500= 0.009430388156019855
# Cost of iteration 15600= 0.00934957246637503
# Cost of iteration 15700= 0.009270095995267479
# Cost of iteration 15800= 0.00919192620320203
# Cost of iteration 15900= 0.009115031585811185
# Cost of iteration 16000= 0.009039381633337434
# Cost of iteration 16100= 0.008964946791991795
# Cost of iteration 16200= 0.008891698427088668
# Cost of iteration 16300= 0.008819608787862894
# Cost of iteration 16400= 0.008748650973880783
# Cost of iteration 16500= 0.008678798902961738
# Cost of iteration 16600= 0.008610027280532211
# Cost of iteration 16700= 0.008542311570338657
# Cost of iteration 16800= 0.008475627966449727
# Cost of iteration 16900= 0.008409953366482063
# Cost of iteration 17000= 0.008345265345988907
# Cost of iteration 17100= 0.008281542133952557
# Cost of iteration 17200= 0.008218762589326047
# Cost of iteration 17300= 0.008156906178572522
# Cost of iteration 17400= 0.008095952954152864
# Cost of iteration 17500= 0.008035883533916351
# Cost of iteration 17600= 0.007976679081349344
# Cost of iteration 17700= 0.007918321286642141
# Cost of iteration 17800= 0.007860792348533858
# Cost of iteration 17900= 0.007804074956899235
# Cost of iteration 18000= 0.0077481522760418815
# Cost of iteration 18100= 0.0076930079286612225
# Cost of iteration 18200= 0.007638625980461544
# Cost of iteration 18300= 0.00758499092537384
# Cost of iteration 18400= 0.007532087671361994
# Cost of iteration 18500= 0.00747990152678662
# Cost of iteration 18600= 0.007428418187301635
# Cost of iteration 18700= 0.0073776237232592995
# Cost of iteration 18800= 0.007327504567600759
# Cost of iteration 18900= 0.007278047504210955
# Cost of iteration 19000= 0.0072292396567169735
# Cost of iteration 19100= 0.007181068477710643
# Cost of iteration 19200= 0.0071335217383764705
# Cost of iteration 19300= 0.007086587518507737
# Cost of iteration 19400= 0.007040254196893514
# Cost of iteration 19500= 0.0069945104420612286
# Cost of iteration 19600= 0.006949345203359147
# Cost of iteration 19700= 0.006904747702364551
# Cost of iteration 19800= 0.006860707424603992
# Cost of iteration 19900= 0.00681721411157217

# %%
def plot_tagged_data(row,col,n_row,n_col,X,Y,parameters): 
    fig=plt.figure(figsize=(row,col))
    
    l,cache = feed_forward(X.T,parameters,activation_function)
    for n in range(row*col):
        img=np.reshape(X[n],(n_row,n_col))
        fig.add_subplot(row, col, n+1)
           
        if(l[0][n]>0.5):
    
            plt.imshow(img,interpolation='none',cmap='RdPu')
        else:
            plt.imshow(img,interpolation='none',cmap='cool')               
    plt.show()

# %%
Ne=N-Nt;
Xe=data[Nt:N,:-1];Ye=data[Nt:N,-1];
Ye = np.where(Ye == -1, 0,1)
plot_tagged_data(10,10,n_row,n_col,Xe,Ye,parameters)

# %%
0.002 * 100
# Out:
# 0.2
