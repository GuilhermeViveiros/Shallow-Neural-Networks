# %%
import scipy
from PIL import Image
import numpy as np
import os
import matplotlib.pylab as plt
import matplotlib.image as mpimg
import importlib

# %%
# sigmoid function
def sigmoid(z):
    s = 1 / (1 + np.exp(-z));
    return s;

# %%
# size of the fst and the last layer, and the hidden layer
# assuming 1 hidden layer
def inicializar_parameters(n_x,n_h,n_y):
    
    w1 = np.random.randn(n_h,n_x) * 0.01;
    b1 = np.zeros((n_h,1));
    w2 = np.random.randn(n_y,n_h) * 0.01;
    b2 = np.zeros((n_y,1));

    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2
    }

    return parameters;

# %%
# i use the non-linear activation function called than, in the output layer i use sigmoid, cause this is a binary classification problem.
def feed_forward(X,parameters):

    w1 = parameters["w1"];
    b1 = parameters["b1"];
    w2 = parameters["w2"];
    b2 = parameters["b2"];

    #feed_foward
    Z1 = np.dot(w1,X) + b1; 
    A1 = np.tanh(Z1);
    Z2 = np.dot(w2,A1) + b2;
    A2 = sigmoid(Z2);

    cache = {
        "Z1" : Z1,
        "A1" : A1,
        "Z2" : Z2,
        "A2" : A2
    }

    return A2, cache;

# %%
def calculate_cost(A2,Yt):
    
    Cost = - np.sum(np.dot(Yt, np.log(A2).T) + np.dot(1 - Yt, np.log(1 - A2).T)) /m;  #cost function

    return Cost;

# %%
#back propagation, calculation of the gradient
def back_propagation(X,Y,cache,parameters):

    A1 = cache["A1"];
    w1 = parameters["w1"];
    w2 = parameters["w2"];
    A2 = cache["A2"];
    
    dZ2 = A2 - Y;
    dW2 = np.dot(dZ2,A1.T)/m;
    dB2 = np.sum(dZ2, axis=1, keepdims = True)/m;
    dZ1 = np.multiply(np.dot(w2.T,dZ2), 1 - np.power(A1, 2));
    dW1 = np.dot(dZ1,X.T)/m;
    dB1 = np.sum(dZ1,axis = 1, keepdims = True)/m;

    grads = {
        "dW2" : dW2,
        "dB2" : dB2,
        "dW1" : dW1,
        "dB1" : dB1
    }

    return grads;

# %%
def otimize_parameters(parameters,grads,learning_rate):
    
    w1 = parameters["w1"];
    w2 = parameters["w2"];
    b1 = parameters["b1"];
    b2 = parameters["b2"];

    
    dW2 = grads["dW2"];
    dB2 = grads["dB2"];
    dW1 = grads["dW1"];
    dB1 = grads["dB1"];

    #uptade de parameters
    w2 = w2 - learning_rate * dW2;
    w1 = w1 - learning_rate * dW1;
    b1 = b1 - learning_rate * dB1;
    b2 = b2 - learning_rate * dB2;

    parameters = {
        "w1" : w1,
        "b1" : b1,
        "w2" : w2,
        "b2" : b2
    }

    return parameters;

# %%
def read_asc_data(filename):    
    f= open(filename,'r') 
    tmp_str=f.readline()
    tmp_arr=tmp_str[:-1].split(' ')
    N=int(tmp_arr[0]);n_row=int(tmp_arr[1]);n_col=int(tmp_arr[2])
    data=np.zeros([N,n_row*n_col+1])
    for n in range(N):
        tmp_str=f.readline()
        tmp_arr=tmp_str[:-1].split(' ')       
        for i in range(n_row*n_col+1):
            data[n][i]=int(tmp_arr[i])
    f.close() 
    return N,n_row,n_col,data

# %%
def model(n_h,number_iterations,learning_rate):

    np.random.seed(3) # we set up a seed so that your output matches ours although the initialization is random.
    parameters = inicializar_parameters(Xt.shape[0],n_h,Yt.shape[0]);

    for i in range(0,number_iterations):

        A2, cache = feed_forward(Xt,parameters);
        cost = calculate_cost(A2,Yt)
        grads = back_propagation(Xt,Yt,cache,parameters);
        parameters = otimize_parameters(parameters,grads,learning_rate);
        
        if(i%100 == 0):
            print("Cost of iteration " + str(i) + "= " + str(cost));

    return parameters;

# %%
#=========== Setting dataset ================
#N,n_row,n_col,data=read_asc_data('./line600.txt')
N,n_row,n_col,data=read_asc_data('./square_circle.txt')
print('find %d images of %d X %d pixels' % (N,n_row,n_col))

#plot_data(10,10,n_row,n_col,data)
Nt=int(N*0.8);I=n_row*n_col; #split training vs test sets
Xt=data[:Nt,:-1];Yt=data[:Nt,-1]
Yt = Yt.reshape(len(Yt),1)

np.place(Yt, Yt!=1, [0])
m = Xt.shape[0]

Xt = Xt.T
Yt = Yt.T

parameters = model(60,6000,0.01)
# Out:
# find 1500 images of 12 X 12 pixels
# Cost of iteration 0= 0.6934902144104429
# Cost of iteration 100= 0.6922841208314222
# Cost of iteration 200= 0.6908085237958294
# Cost of iteration 300= 0.6885808707124773
# Cost of iteration 400= 0.6849492533422236
# Cost of iteration 500= 0.6790876481219158
# Cost of iteration 600= 0.6701977765039377
# Cost of iteration 700= 0.6579443767061484
# Cost of iteration 800= 0.6427227850351449
# Cost of iteration 900= 0.6252400412361109
# Cost of iteration 1000= 0.6058408081819506
# Cost of iteration 1100= 0.584404268526521
# Cost of iteration 1200= 0.5606448154501332
# Cost of iteration 1300= 0.5343283842718746
# Cost of iteration 1400= 0.5053603254292486
# Cost of iteration 1500= 0.47384882821111934
# Cost of iteration 1600= 0.44016241457662486
# Cost of iteration 1700= 0.40494634973522387
# Cost of iteration 1800= 0.3690701090602718
# Cost of iteration 1900= 0.3335124860260469
# Cost of iteration 2000= 0.29922026051935013
# Cost of iteration 2100= 0.26698323871589064
# Cost of iteration 2200= 0.2373563428859733
# Cost of iteration 2300= 0.21063910439924022
# Cost of iteration 2400= 0.186903358555115
# Cost of iteration 2500= 0.16604845122591955
# Cost of iteration 2600= 0.14786275061538415
# Cost of iteration 2700= 0.13207717069948416
# Cost of iteration 2800= 0.11840473511771442
# Cost of iteration 2900= 0.10656612846268426
# Cost of iteration 3000= 0.09630399360042458
# Cost of iteration 3100= 0.08738935305044603
# Cost of iteration 3200= 0.07962307830014037
# Cost of iteration 3300= 0.07283455790296789
# Cost of iteration 3400= 0.06687899051882278
# Cost of iteration 3500= 0.06163417435894208
# Cost of iteration 3600= 0.0569972844519874
# Cost of iteration 3700= 0.05288188769112688
# Cost of iteration 3800= 0.049215301423003587
# Cost of iteration 3900= 0.04593632043129114
# Cost of iteration 4000= 0.04299329524141683
# Cost of iteration 4100= 0.040342525643531114
# Cost of iteration 4200= 0.03794692709935975
# Cost of iteration 4300= 0.03577492817895371
# Cost of iteration 4400= 0.03379956083121685
# Cost of iteration 4500= 0.0319977101561024
# Cost of iteration 4600= 0.03034949537326618
# Cost of iteration 4700= 0.02883775836340823
# Cost of iteration 4800= 0.027447640284387512
# Cost of iteration 4900= 0.026166230283324963
# Cost of iteration 5000= 0.024982273266357807
# Cost of iteration 5100= 0.02388592611213165
# Cost of iteration 5200= 0.022868553696897106
# Cost of iteration 5300= 0.02192255771019224
# Cost of iteration 5400= 0.02104123254561133
# Cost of iteration 5500= 0.02021864360728387
# Cost of iteration 5600= 0.019449524226625218
# Cost of iteration 5700= 0.018729188074620172
# Cost of iteration 5800= 0.01805345451412723
# Cost of iteration 5900= 0.01741858479013606

# %%
def plot_tagged_data(row,col,n_row,n_col,X,Y,parameters): 
    fig=plt.figure(figsize=(row,col))
    
    l,cache = feed_forward(X.T,parameters)
    for n in range(row*col):
        img=np.reshape(X[n],(n_row,n_col))
        fig.add_subplot(row, col, n+1)
           
        if(l[0][n]>0.5):
    
            plt.imshow(img,interpolation='none',cmap='RdPu')
        else:
            plt.imshow(img,interpolation='none',cmap='cool')               
    plt.show()

# %%
Ne=N-Nt;
Xe=data[Nt:N,:-1];Ye=data[Nt:N,-1];
Ye = np.where(Ye == -1, 0,1)
plot_tagged_data(10,10,n_row,n_col,Xe,Ye,parameters)
# Out:
# [[0.98378184 0.01847124 0.01038461 0.9847647  0.02579566 0.01840497
#   0.02176004 0.99366744 0.01884776 0.05019012 0.99175616 0.99125787
#   0.98212931 0.00900502 0.98987928 0.01323772 0.01486832 0.03295838
#   0.03295838 0.04084239 0.01362125 0.97746363 0.01729915 0.97791167
#   0.01726736 0.98628557 0.01702955 0.98796349 0.00891832 0.01136416
#   0.98536063 0.01729915 0.99360764 0.0225523  0.05019012 0.99273786
#   0.02579566 0.02199852 0.97986542 0.02199852 0.03295838 0.99366744
#   0.98748269 0.97768391 0.98955663 0.98987928 0.02199852 0.99012814
#   0.99175616 0.00891832 0.99344854 0.98212931 0.01459964 0.04084239
#   0.01459964 0.02309199 0.01693602 0.02309199 0.01366962 0.01463518
#   0.02309199 0.01873675 0.01434386 0.01323772 0.01362125 0.02309199
#   0.98212931 0.99238277 0.98398761 0.99228686 0.9852087  0.99366744
#   0.01463518 0.05000143 0.00891832 0.98748269 0.97765848 0.01459964
